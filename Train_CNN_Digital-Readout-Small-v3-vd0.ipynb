# %% [markdown]
# # CNN Training
#
# Target of this code is to train a CNN network to classify images of a digital readout to the digits 0 to 9. Additionally a category "NaN" is introduced, to mark images that are not amibiguous.
#
# ### Preparing the training
# * First all libraries are loaded
#     * It is assumed, that they are installed during the Python setup
# * matplotlib is set to print the output inline in the jupyter notebook

# %%
########### Basic Parameters for Running: ################################
    
TFliteNamingAndVersion = "dig1320s3vd0"   # Used for tflite Filename
Training_Percentage = 0.0              # 0.0 = Use all Images for Training
Epoch_Anz = 500

##########################################################################


import tensorflow as tf
import matplotlib.pyplot as plt
import glob
import os
import numpy as np
from sklearn.utils import shuffle
from tensorflow.python import keras
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Dense, InputLayer, Conv2D, MaxPool2D, Flatten, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import History 
from tensorflow.keras.utils import to_categorical
from tensorflow.python.keras.optimizer_v2 import adadelta as adadelta_v2
from PIL import Image 
from pathlib import Path

loss_ges = np.array([])
val_loss_ges = np.array([])

# %matplotlib inline
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)
# Out:
# 2021-11-21 16:14:21.302314: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-11-21 16:14:21.302361: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ### Load training data
# * The data is expected in the "Input_dir"
# * Inside subdirectories are expected from -1, 0, 1, ... 9 in which the pictures are sorted according to their values (=category)
# * Picture size must be 20x32 with 3 color channels (RGB)
# * The filename can be arbitrary
#
# * The images are stored in the x_data[]
# * The expected category for each image in the corresponding y_data[]
#
# * The last step is a shuffle (from sklearn.utils) and split the data into training and validation data

# %%
Input_dir='ziffer_sortiert_vd_resize'

files = glob.glob(Input_dir + '/*.jpg')
x_data = []
y_data = []

for aktfile in files:
    base = os.path.basename(aktfile)
    target = base[0:1]
    if target == "N":
        category = 10                # NaN does not work --> convert to 10
    else:
        category = int(target)
    test_image = Image.open(aktfile)
    test_image = np.array(test_image, dtype="float32")
    x_data.append(test_image)
    y_data.append(np.array([category]))

x_data = np.array(x_data)
y_data = np.array(y_data)
y_data = to_categorical(y_data, 11)
print(x_data.shape)
print(y_data.shape)

x_data, y_data = shuffle(x_data, y_data)

if (Training_Percentage > 0):
    X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=Training_Percentage)
else:
    X_train = x_data
    y_train = y_data
# Out:
# (756, 32, 20, 3)
# (756, 11)

# %% [markdown]
# ### Define the model
#
# The layout of the network ist a typcial CNN network with alternating **Conv2D** and **MaxPool2D** layers. Finished after **flattening** with additional **Dense** layer.
#
# #### Important
# * Shape of the input layer: (32, 20, 3)
# * Number of output layers: 11
# * As loss function "categorical_crossentropy" is choosen, as it is a categories task

# %%
model = Sequential()
model.add(BatchNormalization(input_shape=(32,20,3)))
model.add(Conv2D(32, (3, 3), padding='same', activation="relu"))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(32, (3, 3), padding='same', activation="relu"))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(32, (3, 3), padding='same', activation="relu"))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(128,activation="relu"))
model.add(Dense(11, activation = "softmax"))
model.summary()

model.compile(loss=tf.keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.Adadelta(learning_rate=1.0, rho=0.95), metrics = ["accuracy"])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 32, 20, 3)         12
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 20, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 10, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 10, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 5, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 5, 32)          9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 2, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dense_1 (Dense)              (None, 11)                1419
# =================================================================
# Total params: 53,719
# Trainable params: 53,713
# Non-trainable params: 6
# _________________________________________________________________
# 2021-11-21 16:14:30.150366: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-11-21 16:14:30.150441: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-11-21 16:14:30.150473: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (b99cd54f86b6): /proc/driver/nvidia/version does not exist
# 2021-11-21 16:14:30.151474: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Training
# The input pictures are randomly scattered for brightness, pixel shift variations and rotation angle. This is implemented with a ImageDataGenerator.

# %%
Batch_Size = 4
Shift_Range = 1
Brightness_Range = 0.3
Rotation_Angle = 10
ZoomRange = 0.4

datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], 
                             height_shift_range=[-Shift_Range,Shift_Range],
                             brightness_range=[1-Brightness_Range,1+Brightness_Range],
                             zoom_range=[1-ZoomRange, 1+ZoomRange],
                             rotation_range=Rotation_Angle)

if (Training_Percentage > 0):
    train_iterator = datagen.flow(x_data, y_data, batch_size=Batch_Size)
    validation_iterator = datagen.flow(X_test, y_test, batch_size=Batch_Size)
    history = model.fit(train_iterator, validation_data = validation_iterator, epochs = Epoch_Anz)
else:
    train_iterator = datagen.flow(x_data, y_data, batch_size=Batch_Size)
    history = model.fit(train_iterator, epochs = Epoch_Anz)
# Out:
# Epoch 1/500
# 189/189 [==============================] - 2s 7ms/step - loss: 1.9301 - accuracy: 0.3505
# Epoch 2/500
# 189/189 [==============================] - 1s 6ms/step - loss: 1.1159 - accuracy: 0.6706
# Epoch 3/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.6584 - accuracy: 0.7937
# Epoch 4/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.5309 - accuracy: 0.8466
# Epoch 5/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.4544 - accuracy: 0.8677
# Epoch 6/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.4046 - accuracy: 0.8915
# Epoch 7/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.3650 - accuracy: 0.9140
# Epoch 8/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.3745 - accuracy: 0.8968
# Epoch 9/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.3129 - accuracy: 0.9180
# Epoch 10/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2616 - accuracy: 0.9272
# Epoch 11/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2916 - accuracy: 0.9021
# Epoch 12/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.3107 - accuracy: 0.8968
# Epoch 13/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.2644 - accuracy: 0.9259
# Epoch 14/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2993 - accuracy: 0.9180: 0s - loss: 0.280
# Epoch 15/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2349 - accuracy: 0.9286
# Epoch 16/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2685 - accuracy: 0.9220
# Epoch 17/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2492 - accuracy: 0.9206
# Epoch 18/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.2264 - accuracy: 0.9272
# Epoch 19/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.2432 - accuracy: 0.9127
# Epoch 20/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.2452 - accuracy: 0.9206
# Epoch 21/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.2184 - accuracy: 0.9365
# Epoch 22/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.2248 - accuracy: 0.9299
# Epoch 23/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1884 - accuracy: 0.9352
# Epoch 24/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2046 - accuracy: 0.9339
# Epoch 25/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2022 - accuracy: 0.9352
# Epoch 26/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2133 - accuracy: 0.9312
# Epoch 27/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1847 - accuracy: 0.9365
# Epoch 28/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2012 - accuracy: 0.9299
# Epoch 29/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1864 - accuracy: 0.9259
# Epoch 30/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1960 - accuracy: 0.9352
# Epoch 31/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1956 - accuracy: 0.9272
# Epoch 32/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1882 - accuracy: 0.9392
# Epoch 33/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1795 - accuracy: 0.9392
# Epoch 34/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1645 - accuracy: 0.9444
# Epoch 35/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1861 - accuracy: 0.9405
# Epoch 36/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.2002 - accuracy: 0.9365
# Epoch 37/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1758 - accuracy: 0.9431
# Epoch 38/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1805 - accuracy: 0.9405
# Epoch 39/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1699 - accuracy: 0.9444
# Epoch 40/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1668 - accuracy: 0.9405
# Epoch 41/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1590 - accuracy: 0.9511
# Epoch 42/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1755 - accuracy: 0.9497
# Epoch 43/500
# 189/189 [==============================] - 2s 12ms/step - loss: 0.1885 - accuracy: 0.9352
# Epoch 44/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.1580 - accuracy: 0.9458
# Epoch 45/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.1937 - accuracy: 0.9405
# Epoch 46/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1551 - accuracy: 0.9431
# Epoch 47/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1769 - accuracy: 0.9418
# Epoch 48/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1739 - accuracy: 0.9444
# Epoch 49/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1605 - accuracy: 0.9418
# Epoch 50/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1565 - accuracy: 0.9444
# Epoch 51/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1606 - accuracy: 0.9484
# Epoch 52/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1488 - accuracy: 0.9484
# Epoch 53/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1840 - accuracy: 0.9444
# Epoch 54/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1465 - accuracy: 0.9431
# Epoch 55/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1380 - accuracy: 0.9577
# Epoch 56/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1451 - accuracy: 0.9431
# Epoch 57/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1476 - accuracy: 0.9484
# Epoch 58/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1448 - accuracy: 0.9484
# Epoch 59/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1516 - accuracy: 0.9537
# Epoch 60/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1465 - accuracy: 0.9444
# Epoch 61/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1535 - accuracy: 0.9471
# Epoch 62/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1441 - accuracy: 0.9418
# Epoch 63/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1518 - accuracy: 0.9537
# Epoch 64/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1396 - accuracy: 0.9524
# Epoch 65/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1569 - accuracy: 0.9511
# Epoch 66/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1328 - accuracy: 0.9537
# Epoch 67/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1420 - accuracy: 0.9471
# Epoch 68/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1213 - accuracy: 0.9577
# Epoch 69/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1422 - accuracy: 0.9537
# Epoch 70/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1629 - accuracy: 0.9524
# Epoch 71/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1487 - accuracy: 0.9471
# Epoch 72/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1343 - accuracy: 0.9511
# Epoch 73/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1218 - accuracy: 0.9550
# Epoch 74/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1254 - accuracy: 0.9511
# Epoch 75/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1338 - accuracy: 0.9458
# Epoch 76/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1326 - accuracy: 0.9511
# Epoch 77/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1301 - accuracy: 0.9497
# Epoch 78/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1352 - accuracy: 0.9444
# Epoch 79/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1243 - accuracy: 0.9537
# Epoch 80/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1438 - accuracy: 0.9497
# Epoch 81/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1552 - accuracy: 0.9431
# Epoch 82/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1278 - accuracy: 0.9511
# Epoch 83/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1361 - accuracy: 0.9524
# Epoch 84/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1356 - accuracy: 0.9524
# Epoch 85/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.1328 - accuracy: 0.9537
# Epoch 86/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1383 - accuracy: 0.9563
# Epoch 87/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1057 - accuracy: 0.9656
# Epoch 88/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1110 - accuracy: 0.9603
# Epoch 89/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.1110 - accuracy: 0.9603
# Epoch 90/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1251 - accuracy: 0.9537
# Epoch 91/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1120 - accuracy: 0.9563
# Epoch 92/500
# 189/189 [==============================] - 2s 12ms/step - loss: 0.1100 - accuracy: 0.9643
# Epoch 93/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1205 - accuracy: 0.9550
# Epoch 94/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1284 - accuracy: 0.9590
# Epoch 95/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1143 - accuracy: 0.9550
# Epoch 96/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1492 - accuracy: 0.9524
# Epoch 97/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1062 - accuracy: 0.9563
# Epoch 98/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1406 - accuracy: 0.9471
# Epoch 99/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1436 - accuracy: 0.9511
# Epoch 100/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1158 - accuracy: 0.9550
# Epoch 101/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1191 - accuracy: 0.9550
# Epoch 102/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1141 - accuracy: 0.9590
# Epoch 103/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1185 - accuracy: 0.9511
# Epoch 104/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1389 - accuracy: 0.9511
# Epoch 105/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1387 - accuracy: 0.9524
# Epoch 106/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1078 - accuracy: 0.9590
# Epoch 107/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1044 - accuracy: 0.9616
# Epoch 108/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1281 - accuracy: 0.9590
# Epoch 109/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1126 - accuracy: 0.9577
# Epoch 110/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1496 - accuracy: 0.9524
# Epoch 111/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1155 - accuracy: 0.9563
# Epoch 112/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.0968 - accuracy: 0.9643
# Epoch 113/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0969 - accuracy: 0.9630
# Epoch 114/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1285 - accuracy: 0.9524
# Epoch 115/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1200 - accuracy: 0.9563
# Epoch 116/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1007 - accuracy: 0.9643
# Epoch 117/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1098 - accuracy: 0.9603
# Epoch 118/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1159 - accuracy: 0.9603
# Epoch 119/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1225 - accuracy: 0.9537
# Epoch 120/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1331 - accuracy: 0.9590
# Epoch 121/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.1080 - accuracy: 0.9577
# Epoch 122/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0945 - accuracy: 0.9669
# Epoch 123/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1084 - accuracy: 0.9550
# Epoch 124/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1228 - accuracy: 0.9616
# Epoch 125/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1262 - accuracy: 0.9577
# Epoch 126/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1084 - accuracy: 0.9630
# Epoch 127/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0941 - accuracy: 0.9696
# Epoch 128/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1093 - accuracy: 0.9630
# Epoch 129/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1126 - accuracy: 0.9590
# Epoch 130/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1218 - accuracy: 0.9524
# Epoch 131/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1096 - accuracy: 0.9603
# Epoch 132/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1003 - accuracy: 0.9696
# Epoch 133/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0990 - accuracy: 0.9590
# Epoch 134/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1424 - accuracy: 0.9497
# Epoch 135/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.1234 - accuracy: 0.9524
# Epoch 136/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1171 - accuracy: 0.9537
# Epoch 137/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1143 - accuracy: 0.9577
# Epoch 138/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1224 - accuracy: 0.9603
# Epoch 139/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1388 - accuracy: 0.9524
# Epoch 140/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1253 - accuracy: 0.9524
# Epoch 141/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1185 - accuracy: 0.9471
# Epoch 142/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0788 - accuracy: 0.9735
# Epoch 143/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0982 - accuracy: 0.9735
# Epoch 144/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1116 - accuracy: 0.9590
# Epoch 145/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1041 - accuracy: 0.9616
# Epoch 146/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1207 - accuracy: 0.9537
# Epoch 147/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0910 - accuracy: 0.9669
# Epoch 148/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1359 - accuracy: 0.9590
# Epoch 149/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.1045 - accuracy: 0.9709
# Epoch 150/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1137 - accuracy: 0.9656
# Epoch 151/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0978 - accuracy: 0.9630
# Epoch 152/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1301 - accuracy: 0.9577
# Epoch 153/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1142 - accuracy: 0.9616
# Epoch 154/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1249 - accuracy: 0.9630
# Epoch 155/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1133 - accuracy: 0.9590
# Epoch 156/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1308 - accuracy: 0.9497
# Epoch 157/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0937 - accuracy: 0.9656
# Epoch 158/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.1235 - accuracy: 0.9590
# Epoch 159/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1189 - accuracy: 0.9590
# Epoch 160/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1211 - accuracy: 0.9669
# Epoch 161/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0917 - accuracy: 0.9669
# Epoch 162/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1161 - accuracy: 0.9524
# Epoch 163/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.1142 - accuracy: 0.9577
# Epoch 164/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0970 - accuracy: 0.9590
# Epoch 165/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1162 - accuracy: 0.9643
# Epoch 166/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1115 - accuracy: 0.9550
# Epoch 167/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0748 - accuracy: 0.9722
# Epoch 168/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0965 - accuracy: 0.9643
# Epoch 169/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1138 - accuracy: 0.9683
# Epoch 170/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.0934 - accuracy: 0.9577
# Epoch 171/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0992 - accuracy: 0.9616
# Epoch 172/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1153 - accuracy: 0.9603
# Epoch 173/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0964 - accuracy: 0.9603
# Epoch 174/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0921 - accuracy: 0.9683
# Epoch 175/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1155 - accuracy: 0.9563
# Epoch 176/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1197 - accuracy: 0.9603
# Epoch 177/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0961 - accuracy: 0.9616
# Epoch 178/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1099 - accuracy: 0.9656
# Epoch 179/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0849 - accuracy: 0.9630
# Epoch 180/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1233 - accuracy: 0.9603
# Epoch 181/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1079 - accuracy: 0.9563
# Epoch 182/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1022 - accuracy: 0.9669
# Epoch 183/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1176 - accuracy: 0.9524
# Epoch 184/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1098 - accuracy: 0.9577
# Epoch 185/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0893 - accuracy: 0.9709
# Epoch 186/500
# 189/189 [==============================] - 2s 10ms/step - loss: 0.0962 - accuracy: 0.9656
# Epoch 187/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1080 - accuracy: 0.9669
# Epoch 188/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1062 - accuracy: 0.9656
# Epoch 189/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1201 - accuracy: 0.9616
# Epoch 190/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1222 - accuracy: 0.9563
# Epoch 191/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0970 - accuracy: 0.9696
# Epoch 192/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0896 - accuracy: 0.9656
# Epoch 193/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1056 - accuracy: 0.9656
# Epoch 194/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1107 - accuracy: 0.9656
# Epoch 195/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1145 - accuracy: 0.9603
# Epoch 196/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1158 - accuracy: 0.9643
# Epoch 197/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1040 - accuracy: 0.9683
# Epoch 198/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0761 - accuracy: 0.9683
# Epoch 199/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1208 - accuracy: 0.9511
# Epoch 200/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1509 - accuracy: 0.9590
# Epoch 201/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1186 - accuracy: 0.9643
# Epoch 202/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1100 - accuracy: 0.9669
# Epoch 203/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1204 - accuracy: 0.9630
# Epoch 204/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1258 - accuracy: 0.9590
# Epoch 205/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1104 - accuracy: 0.9630
# Epoch 206/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1062 - accuracy: 0.9643
# Epoch 207/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1093 - accuracy: 0.9643
# Epoch 208/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0758 - accuracy: 0.9735
# Epoch 209/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1119 - accuracy: 0.9643
# Epoch 210/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1155 - accuracy: 0.9603
# Epoch 211/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0873 - accuracy: 0.9683
# Epoch 212/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1032 - accuracy: 0.9696
# Epoch 213/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1180 - accuracy: 0.9616
# Epoch 214/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0920 - accuracy: 0.9683
# Epoch 215/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1145 - accuracy: 0.9630
# Epoch 216/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0936 - accuracy: 0.9735
# Epoch 217/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0867 - accuracy: 0.9735
# Epoch 218/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1179 - accuracy: 0.9656
# Epoch 219/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0964 - accuracy: 0.9643
# Epoch 220/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0734 - accuracy: 0.9722
# Epoch 221/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0822 - accuracy: 0.9696
# Epoch 222/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1033 - accuracy: 0.9709
# Epoch 223/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1243 - accuracy: 0.9497
# Epoch 224/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1052 - accuracy: 0.9630
# Epoch 225/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0844 - accuracy: 0.9683
# Epoch 226/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0814 - accuracy: 0.9696
# Epoch 227/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1003 - accuracy: 0.9616
# Epoch 228/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1016 - accuracy: 0.9643
# Epoch 229/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0869 - accuracy: 0.9709
# Epoch 230/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0812 - accuracy: 0.9696
# Epoch 231/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0909 - accuracy: 0.9643
# Epoch 232/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0744 - accuracy: 0.9749
# Epoch 233/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1414 - accuracy: 0.9550
# Epoch 234/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0738 - accuracy: 0.9735
# Epoch 235/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1000 - accuracy: 0.9590
# Epoch 236/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1200 - accuracy: 0.9537
# Epoch 237/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1021 - accuracy: 0.9590
# Epoch 238/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0955 - accuracy: 0.9643
# Epoch 239/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0951 - accuracy: 0.9709
# Epoch 240/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0785 - accuracy: 0.9709
# Epoch 241/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0785 - accuracy: 0.9683
# Epoch 242/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0999 - accuracy: 0.9616
# Epoch 243/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1098 - accuracy: 0.9643
# Epoch 244/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0830 - accuracy: 0.9709
# Epoch 245/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0834 - accuracy: 0.9722
# Epoch 246/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0990 - accuracy: 0.9696
# Epoch 247/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0800 - accuracy: 0.9696
# Epoch 248/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1098 - accuracy: 0.9683
# Epoch 249/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1125 - accuracy: 0.9683
# Epoch 250/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1252 - accuracy: 0.9550
# Epoch 251/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0841 - accuracy: 0.9709
# Epoch 252/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0973 - accuracy: 0.9669
# Epoch 253/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0799 - accuracy: 0.9735
# Epoch 254/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0928 - accuracy: 0.9630
# Epoch 255/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0838 - accuracy: 0.9643
# Epoch 256/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0859 - accuracy: 0.9696
# Epoch 257/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1008 - accuracy: 0.9590
# Epoch 258/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0966 - accuracy: 0.9669
# Epoch 259/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0940 - accuracy: 0.9616
# Epoch 260/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1057 - accuracy: 0.9683
# Epoch 261/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0965 - accuracy: 0.9656
# Epoch 262/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1231 - accuracy: 0.9590
# Epoch 263/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1095 - accuracy: 0.9603
# Epoch 264/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0788 - accuracy: 0.9762
# Epoch 265/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0857 - accuracy: 0.9735
# Epoch 266/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0803 - accuracy: 0.9696
# Epoch 267/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0836 - accuracy: 0.9722
# Epoch 268/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0931 - accuracy: 0.9683
# Epoch 269/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0917 - accuracy: 0.9709
# Epoch 270/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0731 - accuracy: 0.9722
# Epoch 271/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0975 - accuracy: 0.9656
# Epoch 272/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0878 - accuracy: 0.9630
# Epoch 273/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1316 - accuracy: 0.9656
# Epoch 274/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1111 - accuracy: 0.9656
# Epoch 275/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0969 - accuracy: 0.9683
# Epoch 276/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1000 - accuracy: 0.9735
# Epoch 277/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0678 - accuracy: 0.9696
# Epoch 278/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1038 - accuracy: 0.9656
# Epoch 279/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0860 - accuracy: 0.9735
# Epoch 280/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0896 - accuracy: 0.9696
# Epoch 281/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0723 - accuracy: 0.9709
# Epoch 282/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0962 - accuracy: 0.9683
# Epoch 283/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0721 - accuracy: 0.9788
# Epoch 284/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0613 - accuracy: 0.9788
# Epoch 285/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0874 - accuracy: 0.9749
# Epoch 286/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0809 - accuracy: 0.9749
# Epoch 287/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1136 - accuracy: 0.9590
# Epoch 288/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0928 - accuracy: 0.9709
# Epoch 289/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1091 - accuracy: 0.9603
# Epoch 290/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0818 - accuracy: 0.9749
# Epoch 291/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0940 - accuracy: 0.9669
# Epoch 292/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0866 - accuracy: 0.9696
# Epoch 293/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0835 - accuracy: 0.9696
# Epoch 294/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0812 - accuracy: 0.9749
# Epoch 295/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1124 - accuracy: 0.9696
# Epoch 296/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0805 - accuracy: 0.9696
# Epoch 297/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0790 - accuracy: 0.9722
# Epoch 298/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0914 - accuracy: 0.9669
# Epoch 299/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1124 - accuracy: 0.9524
# Epoch 300/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0789 - accuracy: 0.9749
# Epoch 301/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1143 - accuracy: 0.9709
# Epoch 302/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0873 - accuracy: 0.9722
# Epoch 303/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0725 - accuracy: 0.9696
# Epoch 304/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0738 - accuracy: 0.9749
# Epoch 305/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1133 - accuracy: 0.9603
# Epoch 306/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0939 - accuracy: 0.9630
# Epoch 307/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0922 - accuracy: 0.9709
# Epoch 308/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1160 - accuracy: 0.9722
# Epoch 309/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1017 - accuracy: 0.9696
# Epoch 310/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0568 - accuracy: 0.9815
# Epoch 311/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0876 - accuracy: 0.9788
# Epoch 312/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0655 - accuracy: 0.9775
# Epoch 313/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0871 - accuracy: 0.9696
# Epoch 314/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1065 - accuracy: 0.9722
# Epoch 315/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0898 - accuracy: 0.9735
# Epoch 316/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1017 - accuracy: 0.9722
# Epoch 317/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0919 - accuracy: 0.9696
# Epoch 318/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0866 - accuracy: 0.9762
# Epoch 319/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0926 - accuracy: 0.9590
# Epoch 320/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0901 - accuracy: 0.9683
# Epoch 321/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1065 - accuracy: 0.9669
# Epoch 322/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0842 - accuracy: 0.9709
# Epoch 323/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1241 - accuracy: 0.9590
# Epoch 324/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0747 - accuracy: 0.9749
# Epoch 325/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1251 - accuracy: 0.9603
# Epoch 326/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0717 - accuracy: 0.9683
# Epoch 327/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0947 - accuracy: 0.9696
# Epoch 328/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1105 - accuracy: 0.9656
# Epoch 329/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0778 - accuracy: 0.9683
# Epoch 330/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0982 - accuracy: 0.9683
# Epoch 331/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0703 - accuracy: 0.9722
# Epoch 332/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1163 - accuracy: 0.9683
# Epoch 333/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0797 - accuracy: 0.9656
# Epoch 334/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0681 - accuracy: 0.9749
# Epoch 335/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0881 - accuracy: 0.9735
# Epoch 336/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0853 - accuracy: 0.9722
# Epoch 337/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0826 - accuracy: 0.9709
# Epoch 338/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.1068 - accuracy: 0.9630
# Epoch 339/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0650 - accuracy: 0.9696
# Epoch 340/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0764 - accuracy: 0.9762
# Epoch 341/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0983 - accuracy: 0.9735
# Epoch 342/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0747 - accuracy: 0.9696
# Epoch 343/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0620 - accuracy: 0.9788
# Epoch 344/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0824 - accuracy: 0.9749
# Epoch 345/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0882 - accuracy: 0.9749
# Epoch 346/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1043 - accuracy: 0.9616
# Epoch 347/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0689 - accuracy: 0.9696
# Epoch 348/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0819 - accuracy: 0.9762
# Epoch 349/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1123 - accuracy: 0.9669
# Epoch 350/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0855 - accuracy: 0.9722
# Epoch 351/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0778 - accuracy: 0.9696
# Epoch 352/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0941 - accuracy: 0.9735
# Epoch 353/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1015 - accuracy: 0.9709
# Epoch 354/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0876 - accuracy: 0.9788
# Epoch 355/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1048 - accuracy: 0.9630
# Epoch 356/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0973 - accuracy: 0.9683
# Epoch 357/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0631 - accuracy: 0.9802
# Epoch 358/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0657 - accuracy: 0.9788
# Epoch 359/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0863 - accuracy: 0.9696
# Epoch 360/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0845 - accuracy: 0.9669
# Epoch 361/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0906 - accuracy: 0.9735
# Epoch 362/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0822 - accuracy: 0.9643
# Epoch 363/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0845 - accuracy: 0.9762
# Epoch 364/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0720 - accuracy: 0.9722
# Epoch 365/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0585 - accuracy: 0.9775
# Epoch 366/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1120 - accuracy: 0.9709
# Epoch 367/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0930 - accuracy: 0.9669
# Epoch 368/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0786 - accuracy: 0.9749
# Epoch 369/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0822 - accuracy: 0.9630
# Epoch 370/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.0977 - accuracy: 0.9735
# Epoch 371/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0693 - accuracy: 0.9762
# Epoch 372/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.1202 - accuracy: 0.9735
# Epoch 373/500
# 189/189 [==============================] - 2s 11ms/step - loss: 0.0753 - accuracy: 0.9696
# Epoch 374/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.0689 - accuracy: 0.9735
# Epoch 375/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1072 - accuracy: 0.9616
# Epoch 376/500
# 189/189 [==============================] - 3s 18ms/step - loss: 0.0810 - accuracy: 0.9656
# Epoch 377/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0823 - accuracy: 0.9696
# Epoch 378/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0731 - accuracy: 0.9749
# Epoch 379/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.0902 - accuracy: 0.9630
# Epoch 380/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0841 - accuracy: 0.9683
# Epoch 381/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0801 - accuracy: 0.9669
# Epoch 382/500
# 189/189 [==============================] - 2s 10ms/step - loss: 0.1074 - accuracy: 0.9656
# Epoch 383/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0724 - accuracy: 0.9749
# Epoch 384/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0719 - accuracy: 0.9709
# Epoch 385/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.1046 - accuracy: 0.9643
# Epoch 386/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0824 - accuracy: 0.9722
# Epoch 387/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0904 - accuracy: 0.9735
# Epoch 388/500
# 189/189 [==============================] - 2s 10ms/step - loss: 0.1181 - accuracy: 0.9709
# Epoch 389/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0466 - accuracy: 0.9802
# Epoch 390/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0860 - accuracy: 0.9735
# Epoch 391/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0639 - accuracy: 0.9735
# Epoch 392/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1023 - accuracy: 0.9656
# Epoch 393/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.0673 - accuracy: 0.9802
# Epoch 394/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0876 - accuracy: 0.9722
# Epoch 395/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0801 - accuracy: 0.9735
# Epoch 396/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0815 - accuracy: 0.9762
# Epoch 397/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0843 - accuracy: 0.9722
# Epoch 398/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0869 - accuracy: 0.9749
# Epoch 399/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0488 - accuracy: 0.9815
# Epoch 400/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0901 - accuracy: 0.9656
# Epoch 401/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0859 - accuracy: 0.9683
# Epoch 402/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0917 - accuracy: 0.9709
# Epoch 403/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0703 - accuracy: 0.9749
# Epoch 404/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1259 - accuracy: 0.9709
# Epoch 405/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0453 - accuracy: 0.9802
# Epoch 406/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.0821 - accuracy: 0.9709
# Epoch 407/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0642 - accuracy: 0.9775
# Epoch 408/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.0849 - accuracy: 0.9735
# Epoch 409/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1009 - accuracy: 0.9775
# Epoch 410/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0928 - accuracy: 0.9696
# Epoch 411/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0678 - accuracy: 0.9775
# Epoch 412/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0789 - accuracy: 0.9696
# Epoch 413/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0696 - accuracy: 0.9762
# Epoch 414/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0820 - accuracy: 0.9696
# Epoch 415/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.0711 - accuracy: 0.9735
# Epoch 416/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0859 - accuracy: 0.9669
# Epoch 417/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0765 - accuracy: 0.9735
# Epoch 418/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1114 - accuracy: 0.9709
# Epoch 419/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0496 - accuracy: 0.9841
# Epoch 420/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1169 - accuracy: 0.9696
# Epoch 421/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0615 - accuracy: 0.9788
# Epoch 422/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0744 - accuracy: 0.9841
# Epoch 423/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0801 - accuracy: 0.9709
# Epoch 424/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0790 - accuracy: 0.9815
# Epoch 425/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0933 - accuracy: 0.9722
# Epoch 426/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0852 - accuracy: 0.9762
# Epoch 427/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1006 - accuracy: 0.9735
# Epoch 428/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0876 - accuracy: 0.9683
# Epoch 429/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1150 - accuracy: 0.9696
# Epoch 430/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1155 - accuracy: 0.9656
# Epoch 431/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0948 - accuracy: 0.9735
# Epoch 432/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.1200 - accuracy: 0.9683
# Epoch 433/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0674 - accuracy: 0.9749
# Epoch 434/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1004 - accuracy: 0.9735
# Epoch 435/500
# 189/189 [==============================] - 1s 6ms/step - loss: 0.0737 - accuracy: 0.9722
# Epoch 436/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1074 - accuracy: 0.9696
# Epoch 437/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1059 - accuracy: 0.9735
# Epoch 438/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0911 - accuracy: 0.9696
# Epoch 439/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0710 - accuracy: 0.9735
# Epoch 440/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0675 - accuracy: 0.9722
# Epoch 441/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1007 - accuracy: 0.9643
# Epoch 442/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0604 - accuracy: 0.9802
# Epoch 443/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1119 - accuracy: 0.9696
# Epoch 444/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0669 - accuracy: 0.9868
# Epoch 445/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0704 - accuracy: 0.9762
# Epoch 446/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0790 - accuracy: 0.9709
# Epoch 447/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0764 - accuracy: 0.9735
# Epoch 448/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0732 - accuracy: 0.9735
# Epoch 449/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0968 - accuracy: 0.9696
# Epoch 450/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0887 - accuracy: 0.9669
# Epoch 451/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0736 - accuracy: 0.9722
# Epoch 452/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0881 - accuracy: 0.9656
# Epoch 453/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0879 - accuracy: 0.9775
# Epoch 454/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0800 - accuracy: 0.9735
# Epoch 455/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1110 - accuracy: 0.9630
# Epoch 456/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0638 - accuracy: 0.9762
# Epoch 457/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0587 - accuracy: 0.9828
# Epoch 458/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1290 - accuracy: 0.9590
# Epoch 459/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0527 - accuracy: 0.9854
# Epoch 460/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0842 - accuracy: 0.9735
# Epoch 461/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0638 - accuracy: 0.9722
# Epoch 462/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1136 - accuracy: 0.9775
# Epoch 463/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0832 - accuracy: 0.9669
# Epoch 464/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0697 - accuracy: 0.9749
# Epoch 465/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1052 - accuracy: 0.9683
# Epoch 466/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.0948 - accuracy: 0.9669
# Epoch 467/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0470 - accuracy: 0.9802
# Epoch 468/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1081 - accuracy: 0.9630
# Epoch 469/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0817 - accuracy: 0.9656
# Epoch 470/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0951 - accuracy: 0.9696
# Epoch 471/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0981 - accuracy: 0.9656
# Epoch 472/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0757 - accuracy: 0.9735
# Epoch 473/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0820 - accuracy: 0.9749
# Epoch 474/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0667 - accuracy: 0.9762
# Epoch 475/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0778 - accuracy: 0.9722
# Epoch 476/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0915 - accuracy: 0.9735
# Epoch 477/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0776 - accuracy: 0.9749
# Epoch 478/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0764 - accuracy: 0.9735
# Epoch 479/500
# 189/189 [==============================] - 2s 8ms/step - loss: 0.1248 - accuracy: 0.9696
# Epoch 480/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0984 - accuracy: 0.9683
# Epoch 481/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0868 - accuracy: 0.9709
# Epoch 482/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1158 - accuracy: 0.9683
# Epoch 483/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0720 - accuracy: 0.9735
# Epoch 484/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0782 - accuracy: 0.9762
# Epoch 485/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.1017 - accuracy: 0.9841
# Epoch 486/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0927 - accuracy: 0.9735
# Epoch 487/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.1014 - accuracy: 0.9722
# Epoch 488/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0716 - accuracy: 0.9815
# Epoch 489/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0544 - accuracy: 0.9815
# Epoch 490/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0958 - accuracy: 0.9696
# Epoch 491/500
# 189/189 [==============================] - 1s 8ms/step - loss: 0.0747 - accuracy: 0.9762
# Epoch 492/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0747 - accuracy: 0.9762
# Epoch 493/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0637 - accuracy: 0.9775
# Epoch 494/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0662 - accuracy: 0.9709
# Epoch 495/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0961 - accuracy: 0.9762
# Epoch 496/500
# 189/189 [==============================] - 2s 9ms/step - loss: 0.0782 - accuracy: 0.9669
# Epoch 497/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0935 - accuracy: 0.9683
# Epoch 498/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0605 - accuracy: 0.9735
# Epoch 499/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0791 - accuracy: 0.9735
# Epoch 500/500
# 189/189 [==============================] - 1s 7ms/step - loss: 0.0918 - accuracy: 0.9722

# %% [markdown]
# ### Learing result
#
# * Visualization of the training and validation results

# %%
loss_ges = np.append(loss_ges, history.history['loss'])
plt.semilogy(history.history['loss'])

if (Training_Percentage > 0):
    val_loss_ges = np.append(val_loss_ges, history.history['val_loss'])
    plt.semilogy(history.history['val_loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','eval'], loc='upper left')
plt.show()

# %% [markdown]
# ### Check the model by hand
#
# * The following code uses the trained model to check the deviation for each picture.
# * x-axis walks through each pixel, y-axis shows the result

# %% [markdown]
# ### Check each image for expected and deviation
# * setting the switch "only_deviation = true" will only print the images for which the classification and the CNN-result deviates
#
# The output contains the following information:
#
# | Filename      | Expected Category           | Predicted Category        |
# |------------- |:-----------------------------:|--------------|
# | ziffer_sortiert_resize_NaN/5\Ziffer_4_0034.jpg | 4  | -1 |

# %%
Input_dir='ziffer_sortiert_vd_resize'
res = []
only_deviation = True
show_wrong_image = True

files = glob.glob(Input_dir + '/*.jpg')

for aktfile in files:
    base = os.path.basename(aktfile)
    target = base[0:1]
    if target == "N":
        zw1 = -1
    else:
        zw1 = int(target)
    expected_class = zw1
    image_in = Image.open(aktfile)
    test_image = np.array(image_in, dtype="float32")
    img = np.reshape(test_image,[1,32,20,3])
    classes = np.argmax(model.predict(img), axis=-1)
    classes = classes[0]
    if classes == 10: 
        classes = -1
    zw2 = classes
    zw3 = zw2 - zw1
    res.append(np.array([zw1, zw2, zw3]))
    if only_deviation == True:
        if str(classes) != str(expected_class):
            print(aktfile + " " + str(expected_class) +  " " + str(classes))
            if show_wrong_image == True:
                display(image_in)
    else:
        print(aktfile + " " + aktsubdir +  " " + str(classes))
        

res = np.asarray(res)


plt.plot(res[:,0])
plt.plot(res[:,1])
plt.title('Result')
plt.ylabel('Digital Value')
plt.xlabel('#Picture')
plt.legend(['real','model'], loc='upper left')
plt.show()
# Out:
# ziffer_sortiert_vd_resize/0_dig100_20211112-064016.jpg 0 6
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=20x32 at 0x7F8AEC2F2250>
# ziffer_sortiert_vd_resize/0_dig10_20211106-201557.jpg 0 6
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=20x32 at 0x7F8AEC3D8940>
# ziffer_sortiert_vd_resize/2_dig01_20211111-001219.jpg 2 3
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=20x32 at 0x7F8AEC181880>
# ziffer_sortiert_vd_resize/2_dig01_20211111-012719.jpg 2 3
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=20x32 at 0x7F8AEC1813A0>
# ziffer_sortiert_vd_resize/3_dig01_20211105-203744.jpg 3 6
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=20x32 at 0x7F8AEC17DF40>
# ziffer_sortiert_vd_resize/3_dig01_20211111-093825.jpg 3 6
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=20x32 at 0x7F8AEC267AC0>
# ziffer_sortiert_vd_resize/3_dig01_20211111-141432.jpg 3 8
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=20x32 at 0x7F8AEC36C9D0>
# ziffer_sortiert_vd_resize/3_dig1_20211109-133351.jpg 3 1
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=20x32 at 0x7F8AEC027850>
# ziffer_sortiert_vd_resize/4_dig01_20211107-105055.jpg 4 6
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=20x32 at 0x7F8ACF72B550>
# ziffer_sortiert_vd_resize/4_dig01_20211107-133055.jpg 4 6
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=20x32 at 0x7F8AEC34F3A0>
# ziffer_sortiert_vd_resize/4_dig01_20211108-002054.jpg 4 6
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=20x32 at 0x7F8ACF72B550>
# ziffer_sortiert_vd_resize/6_dig01_20211109-082849.jpg 6 8
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=20x32 at 0x7F8AEC36C5B0>
# ziffer_sortiert_vd_resize/7_dig01_20211108-093553.jpg 7 3
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=20x32 at 0x7F8AEC17D9D0>
# ziffer_sortiert_vd_resize/7_dig01_20211108-115710.jpg 7 3
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=20x32 at 0x7F8B05962D00>

# %% [markdown]
# ### Save the model
#
# * Save the model to the file with the "h5" file format

# %%
FileName = TFliteNamingAndVersion

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open(FileName + ".tflite", "wb").write(tflite_model)

# %%
FileName = TFliteNamingAndVersion + "q.tflite"

import tensorflow as tf

def representative_dataset():
    for n in range(x_data[0].size):
      data = np.expand_dims(x_data[5], axis=0)
      yield [data.astype(np.float32)]
        
converter2 = tf.lite.TFLiteConverter.from_keras_model(model)
converter2.representative_dataset = representative_dataset
converter2.optimizations = [tf.lite.Optimize.DEFAULT]
converter2.representative_dataset = representative_dataset
tflite_quant_model = converter2.convert()

open(FileName, "wb").write(tflite_quant_model)
print(FileName)
Path(FileName).stat().st_size

# %% [markdown]
# Checking the images shows, that this are border line images, which can be interpreted as a good digit or a faulty one.
